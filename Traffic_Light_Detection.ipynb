# %% [markdown]
# <a href="https://colab.research.google.com/github/Ohmdatazwld5/AI-Caption-Generator/blob/main/Traffic_Light_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics -q

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")

# %%
# !touch data.yaml

# %%
model.train(data = "/content/data.yaml", epochs = 5)
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
infer = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/All data/test/images", save = True, save_txt = True)

# %%
# !yolo detect predict model="/content/runs/detect/train/weights/best.pt" source="/content/stock-footage-chicago-traffic-light-turns-from-green-to-red-at-downtown-financial-district-intersection.webm"
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 218 layers, 25841497 parameters, 0 gradients
#
# video 1/1 (1/549) /content/stock-footage-chicago-traffic-light-turns-from-green-to-red-at-downtown-financial-district-intersection.webm: 384x640 1 green, 1047.0ms
# video 1/1 (2/549) /content/stock-footage-chicago-traffic-light-turns-from-green-to-red-at-downtown-financial-district-intersection.webm: 384x640 1 green, 1459.1ms
# video 1/1 (3/549) /content/stock-footage-chicago-traffic-light-turns-from-green-to-red-at-downtown-financial-district-intersection.webm: 384x640 1 green, 1545.9ms
# video 1/1 (4/549) /content/stock-footage-chicago-traffic-light-turns-from-green-to-red-at-downtown-financial-district-intersection.webm: 384x640 1 green, 1585.0ms
# video 1/1 (5/549) /content/stock-footage-chicago-traffic-light-turns-from-green-to-red-at-downtown-financial-district-intersection.webm: 384x640 1 green, 1136.6ms
# ...
